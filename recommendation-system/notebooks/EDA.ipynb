# %%
import numpy as np
import pandas as pd
import os

# %%
df = pd.read_csv('../data/processed/recommendation_features.csv')

# %%
df
# Out:
#     Ticker  PE_Ratio  Forward_PE  PBV_Ratio  PEG_Ratio      Beta  \
# 0        A -0.158016    0.042180  -0.016714       1.26  0.715450
# 1     AAPL -0.059223    0.167043   0.511594       2.46  0.282971
# 2     ABBV  0.468721   -0.010156  -1.478634       0.47 -1.377836
# 3     ABNB -0.055229    0.116426   0.056952       1.35  0.396664
# 4      ABT -0.155346    0.017029  -0.038039       1.41 -0.446001
# ..     ...       ...         ...        ...        ...       ...
# 498    XYZ -0.070529    0.014164  -0.052583       0.84  3.635797
# 499    YUM -0.120666    0.084797  -0.155458       1.99 -0.713513
# 500    ZBH -0.150463   -0.033600  -0.058922       0.66 -0.824977
# 501   ZBRA -0.134984   -0.023817  -0.037156       0.51  1.500154
# 502    ZTS -0.221090    0.020441   0.114350       1.99 -0.017980
#
#      Debt_to_Equity  Current_Ratio        ROE  Profit_Margin  ...  \
# 0         -0.171755          2.066  -0.075203        0.18259  ...
# ...
